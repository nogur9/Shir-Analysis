# %%
import pandas as pd
import datetime
import numpy as np

# %%
df1 = pd.read_csv("../subscriptions.csv")
df2 = pd.read_csv("../subscriptions_new.csv")
email = 'Customer Email'
name = 'Customer Name'

# %%
name, email = f"{name}_x", f"{email}_x"
can = "Canceled At (UTC)"
can_x, can_y = f"{can}_x", f"{can}_y"

# %%
in_cols = [name, email, can_x, can_y]

# %%
common_cols = [i for i in df1 if i in df2]
common_cols.remove('id')
mrg = df1.merge(df2, on='id', how='left')

# %%
eq = []
not_eq = []
for col in common_cols:
    tmp  = mrg.dropna(subset=[f"{col}_x", f"{col}_y"], how='all')
    equal = (tmp[f"{col}_x"] == tmp[f"{col}_y"]).all()
    if not equal:
        not_eq.append(col)
    else:
        eq.append(col)

# %%
not_eq
# Out:
# ['Amount',
#  'Status',
#  'Start (UTC)',
#  'Current Period Start (UTC)',
#  'Current Period End (UTC)',
#  'Trial End (UTC)',
#  'Canceled At (UTC)',
#  'Ended At (UTC)']

# %%
col = 'Current Period Start (UTC)'
tmp  = mrg.dropna(subset=[f"{col}_x", f"{col}_y"], how='all')
tmp[~pd.Series.eq(tmp[f"{col}_x"], tmp[f"{col}_y"])][in_cols + [f"{col}_x", f"{col}_y"]]
# Out:
#              Customer Name_x              Customer Email_x  \
# 0                 Azlina Yeo      azlinayeo@googlemail.com
# 2                 Yingshi Ji         yingshijinb@gmail.com
# 5                 Tali Sayar              tali07@gmail.com
# 7         Ms pavlina petrova          pav_ivan@yahoo.co.uk
# 8    Muhammad Hassaan Sarwar         hassaan2312@gmail.com
# 9         Anirudh Manchiraju          anirudhmvr@gmail.com
# 10         Priya swaminathan        priya88swami@gmail.com
# 15           Tina Teotia Das            tinateotia@nhs.net
# 16           Miss M L Crosby        marshacrosby@gmail.com
# 17               MR G SUAREZ           mrgsuarez@yahoo.com
# 21              Miss E Lyons        elise.lyons@icloud.com
# 22               Kajal Kiran   kajalsharma198306@gmail.com
# 28              kritika vats         kittushwa55@gmail.com
# 32          Katie Waldegrave         kwaldegrave@yahoo.com
# 43               MS  ABIDOYE        nayo.abidoye@gmail.com
# 48                   R JATTI            SowmyaRJ@gmail.com
# 51           Oliver Fetiveau           ofetiveau@gmail.com
# 57                M a waheed   abbasi_adil2004@hotmaik.com
# 66               Tami Chuang          tamichuang@gmail.com
# 71               Mayank Jain       jmayankjain97@gmail.com
# 74            Roselind Owusu        mamekyerewaa@gmail.com
# 75              Lukas Dendis        dendislukas0@gmail.com
# 82             DR Q CHANDRAN      qudsiachandran@gmail.com
# 86                Max Morris        maxmorris029@gmail.com
# 87    Devi Namakkal sengodan           deviponnu@gmail.com
# 91               Mrs A Patel          tejus.asha@gmail.con
# 91              2025-08-14 14:28
# 92              2025-08-14 12:54
# 105             2025-07-26 13:25
# 108             2025-07-21 18:19
# 109             2025-08-13 00:00
# 113             2025-08-13 21:06
# 117             2025-08-09 16:24
# 118             2025-08-09 15:46
# 120             2025-08-02 15:57
# 121             2025-07-27 10:44
# 122             2025-08-09 22:47
# 143             2025-07-18 20:55
# 146             2025-08-10 18:19
# 150             2025-08-13 15:33
# 153             2025-08-07 19:58
# 158             2025-08-02 16:53
# 164             2025-07-19 11:21
# 174             2025-08-10 18:45
# 191             2025-08-04 17:54
# 196             2025-08-07 11:10
# 207             2025-08-02 23:29
# 211             2025-07-22 16:43
# 215             2025-07-20 01:14
# 220             2025-08-03 16:22
# 223             2025-07-27 10:45
# 232             2025-08-05 19:00
# 237             2025-07-28 17:04
# 240             2025-08-14 19:23
# 245             2025-08-07 13:41
# 250             2025-08-13 21:10
# 252             2025-07-19 00:26
# 263             2025-07-17 16:45

# %% [markdown]
# ### notes

# %% [markdown]
# #### plan changed

# %%
col = 'Amount'
tmp  = mrg.dropna(subset=[f"{col}_x", f"{col}_y"], how='all')
tmp[~pd.Series.eq(tmp[f"{col}_x"], tmp[f"{col}_y"])][[name, email, f"{col}_x", f"{col}_y"]]

# %% [markdown]
# #### new canceled

# %%
col = 'Status'
tmp  = mrg.dropna(subset=[f"{col}_x", f"{col}_y"], how='all')
tmp[~pd.Series.eq(tmp[f"{col}_x"], tmp[f"{col}_y"])][in_cols + [f"{col}_x", f"{col}_y"]]

# %% [markdown]
# #### start incompatibality

# %%
col = 'Start (UTC)'
tmp  = mrg.dropna(subset=[f"{col}_x", f"{col}_y"], how='all')
tmp[~pd.Series.eq(tmp[f"{col}_x"], tmp[f"{col}_y"])][in_cols + [f"{col}_x", f"{col}_y"]]
# Out:
#     Customer Name_x          Customer Email_x Canceled At (UTC)_x  \
# 0        Azlina Yeo  azlinayeo@googlemail.com                 NaN
# 66      Tami Chuang      tamichuang@gmail.com                 NaN
# 75     Lukas Dendis    dendislukas0@gmail.com                 NaN
# 153  Craig Petersen        craig@2deviate.com                 NaN
# 191  Antonio Sawaya      sawaya_a@hotmail.com                 NaN
# 207  Gerald PRETEAU  gerald.preteau@gmail.com                 NaN
#
#     Canceled At (UTC)_y     Start (UTC)_x     Start (UTC)_y
# 0      2025-07-20 13:05  2025-07-13 17:22  2025-07-20 13:05
# 66                  NaN  2025-02-09 08:48  2025-08-07 16:07
# 75                  NaN  2025-01-31 17:27  2025-07-31 16:15
# 153                 NaN  2025-05-21 18:06  2025-08-07 19:58
# 191                 NaN  2024-07-23 08:09  2025-08-04 17:54
# 207                 NaN  2025-05-04 13:53  2025-08-02 23:29
