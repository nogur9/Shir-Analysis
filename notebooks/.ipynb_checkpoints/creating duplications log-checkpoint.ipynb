# %%
import pandas as pd
import seaborn as sns
import plotly
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display, clear_output
from collections import defaultdict
import datetime

# %%
def contains_shir(row):
    # exception
    if row[email] == 'kshirjarohannaik@gmail.com':
        return False
    elif 'shir' in row[email]:
        return True
    elif 'shir' in row[name]:
        return True
    else:
        return False

# %%
canceled_at_col = "Canceled At (UTC)"
ended_at_col = "Ended At (UTC)"
start_at_col = "Start Date (UTC)"

df = pd.read_csv("../data/subscriptions.csv")
email = 'Customer Email'
name = 'Customer Name'
c_id = 'Customer ID'

df[email] = df[email].str.lower()
df[name] = df[name].str.lower()


# no empty values
print(f"{df[email].isna().sum() = }")
print(f"{df[name].isna().sum() = }")
# Out:
# df[email].isna().sum() = 0
# df[name].isna().sum() = 0

# %%
shir_mask = df.apply(contains_shir, axis=1)
df = df[~shir_mask]


for col in [start_at_col, canceled_at_col, ended_at_col]:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors="coerce")

# %%
def assign_duplicate_group_ids(df, email_col, name_col):
    df = df.copy()  # do not mutate caller
    # Ensure positional alignment 0..n-1
    df = df.reset_index(drop=True)
    n = len(df)

    # Group labels as arrays (positional)
    e_group = df.groupby(email_col).ngroup().to_numpy()
    n_group = df.groupby(name_col).ngroup().to_numpy()

    # Build adjacency by shared email OR shared name
    email_to_rows = defaultdict(list)
    name_to_rows  = defaultdict(list)
    for i in range(n):
        email_to_rows[e_group[i]].append(i)
        name_to_rows[n_group[i]].append(i)

    # DFS over rows (0..n-1), using only positional indices
    visited = set()
    group_id = [-1] * n
    current_gid = 0

    for start in range(n):
        if start in visited:
            continue
        stack = [start]
        while stack:
            cur = stack.pop()
            if cur in visited:
                continue
            visited.add(cur)
            group_id[cur] = current_gid

            # push all rows sharing this row's email
            for nbr in email_to_rows[e_group[cur]]:
                if nbr not in visited:
                    stack.append(nbr)
            # push all rows sharing this row's name
            for nbr in name_to_rows[n_group[cur]]:
                if nbr not in visited:
                    stack.append(nbr)

        current_gid += 1

    df["group_id"] = group_id
    return df

# %%
def collapse_duplicate_groups(
    df: pd.DataFrame,
    group_col: str = "group_id",
    min_col: str = "column 1",
    max_col: str = "column 2",
    sort_keys=None,       # e.g., ["some_priority_col", "created_at"]
) -> pd.DataFrame:
    """
    For each group in `group_col`, collapse to a single row:
      - min of `min_col`
      - max of `max_col`
      - first for all other columns
    If `sort_keys` is provided, we sort before taking 'first' to make it deterministic.
    """
    if sort_keys is not None:
        df = df.sort_values(sort_keys).copy()
    else:
        df = df.copy()  # keep current order; 'first' will follow this order

    # Build the aggregation map
    agg_map = {min_col: "min", max_col: "max"}

    for c in df.columns:
        if c not in (group_col, min_col, max_col):
            agg_map[c] = "first"

    out = df.groupby(group_col, as_index=False).agg(agg_map)
    return out

# %%
dups = assign_duplicate_group_ids(df, email_col=email, name_col=name)

# %%
 new_df = collapse_duplicate_groups(
    df = dups,
    group_col = "group_id",
    min_col = start_at_col,
    max_col = canceled_at_col
)

# %%
dup_handler = pd.read_excel("../data/handling duplicates.xlsx")
guide = dup_handler.groupby("group_id")["Unnamed: 3"]
  .apply(lambda x: x[x != ""].iloc[0]).to_dict()

# %%
"multiple start - end"

# %%
non_duplicates = dups[~dups['group_id'].isin(guide.keys())]
multiple_start_end = duplicates[duplicates['group_id'].map(guide) == "multiple start - end"]

# %%
duplicates = dups[dups['group_id'].isin(guide.keys())]

# %%
didnt_quit = duplicates[duplicates['group_id'].map(guide) == "didn't_quit"]
single_start_end = duplicates[duplicates['group_id'].map(guide) == "single_start-end"]

# %%
clean_single_start_end = collapse_duplicate_groups(
    df = single_start_end,
    group_col = "group_id",
    min_col = start_at_col,
    max_col = canceled_at_col
)

# %%
clean_didnt_quit = collapse_duplicate_groups(
    df = didnt_quit,
    group_col = "group_id",
    min_col = start_at_col,
    max_col = canceled_at_col
)

# %%
clean_didnt_quit[canceled_at_col] = pd.NaT

# %%
# Out:
#     group_id    Start Date (UTC) Canceled At (UTC)  \
# 0          0 2025-01-28 16:14:00               NaT
# 1          2 2025-01-30 17:48:00               NaT
# 2          8 2025-06-10 11:47:00               NaT
# 3         12 2024-10-20 16:16:00               NaT
# 4         13 2024-08-06 16:07:00               NaT
# 5         33 2025-03-29 18:40:00               NaT
# 6         35 2024-09-11 06:19:00               NaT
# 7         36 2025-01-06 19:02:00               NaT
# 8         37 2024-09-16 17:11:00               NaT
# 9         51 2025-02-25 17:03:00               NaT
# 10        92 2024-10-18 23:00:00               NaT
# 11       121 2024-06-09 06:51:00               NaT
# 12       167 2023-10-30 14:53:00               NaT
# 13       189 2024-02-13 21:10:00               NaT
# 14       190 2023-12-12 17:49:00               NaT
# 15       205 2023-10-03 19:12:00               NaT
#
#                               id         Customer ID  \
# 0   sub_1RkTbeLLDYopDCcGez5KYmW7  cus_SfpGzDnMyWQpQ3
# 1   sub_1Ri1XfLLDYopDCcGQQHFawIZ  cus_RgOe9AD4XRTWtl
# 2   sub_1Rb6VkLLDYopDCcG18027jlK  cus_STNPe2zBRCwD0I
# 3   sub_1RYQ4WLLDYopDCcGMG0rTq6N  cus_R4A8b4ACPi53SD
# 4   sub_1RX0k1LLDYopDCcGNnYJEdOf  cus_Qc4G9Tt7QWgPMe
# 5   sub_1RD4YBLLDYopDCcG7k50Gx9B  cus_S28ZA8wYVlgpxJ
# 6   sub_1RBL9fLLDYopDCcGrvLfbltR  cus_QpOhYqARNS58aM
# 7   sub_1RBL7VLLDYopDCcGrXnGeWO3  cus_RXQQvNsaAC84Cu
# 8   sub_1RBL06LLDYopDCcG6G65D6YR  cus_QrRLhnsJhjoVzB
# 9   sub_1QxZr0LLDYopDCcGyr9wmgdy  cus_RrIRjiYHnxQwdW
# 10  sub_1QVMIyLLDYopDCcGsXfAvYL7  cus_R0l75hdR431qkS
# 11  sub_1Q8MupLLDYopDCcGCP7itaDk  cus_QGBy6SbE0daouw
# 12  sub_1PMFDSLLDYopDCcG9vhq2tez  cus_QCeWhbUC4VQyiI
# 13  sub_1OwlNCLLDYopDCcGs6scuxZP  cus_PmK14FjH0rMgMJ
# 14  sub_1Ov27hLLDYopDCcGG3yvuCYe  cus_PkXCZfFrCvu80P
# 15  sub_1ODVAvLLDYopDCcGfTrQOoff  cus_P1YHjP7i44eXZ9
#
#                 Customer Email  Quantity  Amount    Status     Created (UTC)  \
# 0     azlinayeo@googlemail.com         1   220.0  trialing  2025-07-13 17:22
# 1         moshed88@hotmail.com         1   540.0    active  2025-07-06 23:00
# 2         anirudhmvr@gmail.com         1   220.0    active  2025-06-17 20:53
# 3           tinateotia@nhs.net         1    99.0    active  2025-06-10 11:10
# 4       marshacrosby@gmail.com         1    60.0    active  2025-06-06 13:55
# 5       jeojeo0328@hotmail.com         1  1080.0    active  2025-04-12 13:56
# 6    marcela.bletzer@gmail.com         1   420.0    active  2025-04-07 19:16
# 7         hgajeens@hotmail.com         1   420.0    active  2025-04-07 19:14
# 8       b.armendariz@ucl.ac.uk         1  1080.0    active  2025-04-07 19:06
